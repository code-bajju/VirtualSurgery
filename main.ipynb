# %%
import cv2
import numpy as np

hand_hist = None
traverse_point = []
total_rectangle = 9
hand_rect_one_x = None
hand_rect_one_y = None

hand_rect_two_x = None
hand_rect_two_y = None


def rescale_frame(frame, wpercent=130, hpercent=130):
    width = int(frame.shape[1] * wpercent / 100)
    height = int(frame.shape[0] * hpercent / 100)
    return cv2.resize(frame, (width, height), interpolation=cv2.INTER_AREA)


def contours(hist_mask_image):
    gray_hist_mask_image = cv2.cvtColor(hist_mask_image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray_hist_mask_image, 0, 255, 0)
    cont, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    return cont

def draw_rect(frame):
    rows, cols, _ = frame.shape
    global total_rectangle, hand_rect_one_x, hand_rect_one_y, hand_rect_two_x, hand_rect_two_y

    hand_rect_one_x = np.array(
        [6 * rows / 20, 6 * rows / 20, 6 * rows / 20, 9 * rows / 20, 9 * rows / 20, 9 * rows / 20, 12 * rows / 20,
         12 * rows / 20, 12 * rows / 20], dtype=np.uint32)

    hand_rect_one_y = np.array(
        [9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20, 10 * cols / 20, 11 * cols / 20, 9 * cols / 20,
         10 * cols / 20, 11 * cols / 20], dtype=np.uint32)

    hand_rect_two_x = hand_rect_one_x + 10
    hand_rect_two_y = hand_rect_one_y + 10

    for i in range(total_rectangle):
        cv2.rectangle(frame, (hand_rect_one_y[i], hand_rect_one_x[i]),
                      (hand_rect_two_y[i], hand_rect_two_x[i]),
                      (0, 255, 0), 1)

    return frame


def hand_histogram(frame):
    global hand_rect_one_x, hand_rect_one_y

    hsv_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    roi = np.zeros([90, 10, 3], dtype=hsv_frame.dtype)

    for i in range(total_rectangle):
        roi[i * 10: i * 10 + 10, 0: 10] = hsv_frame[hand_rect_one_x[i]:hand_rect_one_x[i] + 10,
                                          hand_rect_one_y[i]:hand_rect_one_y[i] + 10]

    hand_hist = cv2.calcHist([roi], [0, 1], None, [180, 256], [0, 180, 0, 256])
    return cv2.normalize(hand_hist, hand_hist, 0, 255, cv2.NORM_MINMAX)


def hist_masking(frame, hist):
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    dst = cv2.calcBackProject([hsv], [0, 1], hist, [0, 180, 0, 256], 1)

    disc = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (31, 31))
    cv2.filter2D(dst, -1, disc, dst)

    ret, thresh = cv2.threshold(dst, 150, 255, cv2.THRESH_BINARY)

    # thresh = cv2.dilate(thresh, None, iterations=5)

    thresh = cv2.merge((thresh, thresh, thresh))

    return cv2.bitwise_and(frame, thresh)


def centroid(max_contour):
    moment = cv2.moments(max_contour)
    if moment['m00'] != 0:
        cx = int(moment['m10'] / moment['m00'])
        cy = int(moment['m01'] / moment['m00'])
        return cx, cy
    else:
        return None


def farthest_point(defects, contour, centroid):
    if defects is not None and centroid is not None:
        s = defects[:, 0][:, 0]
        cx, cy = centroid

        x = np.array(contour[s][:, 0][:, 0], dtype=np.float64)
        y = np.array(contour[s][:, 0][:, 1], dtype=np.float64)

        xp = cv2.pow(cv2.subtract(x, cx), 2)
        yp = cv2.pow(cv2.subtract(y, cy), 2)
        dist = cv2.sqrt(cv2.add(xp, yp))

        dist_max_i = np.argmax(dist)

        if dist_max_i < len(s):
            farthest_defect = s[dist_max_i]
            farthest_point = tuple(contour[farthest_defect][0])
            return farthest_point
        else:
            return None


def draw_circles(frame, traverse_point):
    if traverse_point is not None:
        for i in range(len(traverse_point)):
            cv2.circle(frame, traverse_point[i], int(5 - (5 * i * 3) / 100), [0, 255, 255], -1)


def manage_image_opr(frame, hand_hist):
    hist_mask_image = hist_masking(frame, hand_hist)

    hist_mask_image = cv2.erode(hist_mask_image, None, iterations=2)
    hist_mask_image = cv2.dilate(hist_mask_image, None, iterations=2)

    contour_list = contours(hist_mask_image)
    max_cont = max(contour_list, key=cv2.contourArea)

    cnt_centroid = centroid(max_cont)
    cv2.circle(frame, cnt_centroid, 5, [255, 0, 255], -1)

    if max_cont is not None:
        hull = cv2.convexHull(max_cont, returnPoints=False)
        defects = cv2.convexityDefects(max_cont, hull)
        far_point = farthest_point(defects, max_cont, cnt_centroid)
        print("Centroid : " + str(cnt_centroid) + ", farthest Point : " + str(far_point))
        cv2.circle(frame, far_point, 5, [0, 0, 255], -1)
        if len(traverse_point) < 20:
            traverse_point.append(far_point)
        else:
            traverse_point.pop(0)
            traverse_point.append(far_point)

        draw_circles(frame, traverse_point)


def main():
    global hand_hist
    is_hand_hist_created = False
    capture = cv2.VideoCapture(0)

    while capture.isOpened():
        pressed_key = cv2.waitKey(1)
        _, frame = capture.read()
        frame = cv2.flip(frame, 1)

        if pressed_key & 0xFF == ord('z'):
            is_hand_hist_created = True
            hand_hist = hand_histogram(frame)

        if is_hand_hist_created:
            manage_image_opr(frame, hand_hist)

        else:
            frame = draw_rect(frame)

        cv2.imshow("Live Feed", rescale_frame(frame))

        if pressed_key == 27:
            break

    cv2.destroyAllWindows()
    capture.release()


if __name__ == '__main__':
    main()
# Out:
# Centroid : (671, 415), farthest Point : (815, 719)
# Centroid : (680, 428), farthest Point : (977, 717)
# Centroid : (674, 428), farthest Point : (858, 719)
# Centroid : (682, 428), farthest Point : (858, 719)
# Centroid : (685, 427), farthest Point : (884, 707)
# Centroid : (680, 423), farthest Point : (806, 718)
# Centroid : (678, 417), farthest Point : (721, 719)
# Centroid : (676, 413), farthest Point : (730, 719)
# Centroid : (672, 419), farthest Point : (731, 719)
# Centroid : (681, 423), farthest Point : (830, 719)
# Centroid : (691, 436), farthest Point : (984, 719)
# Centroid : (683, 422), farthest Point : (837, 713)
# Centroid : (663, 394), farthest Point : (721, 719)
# Centroid : (673, 426), farthest Point : (844, 719)
# Centroid : (675, 419), farthest Point : (809, 719)
# Centroid : (677, 425), farthest Point : (796, 719)
# Centroid : (667, 427), farthest Point : (789, 718)
# Centroid : (657, 450), farthest Point : (868, 713)
# Centroid : (629, 457), farthest Point : (787, 719)
# Centroid : (608, 465), farthest Point : (928, 371)
# Centroid : (572, 475), farthest Point : (824, 668)
# Centroid : (537, 475), farthest Point : (877, 387)
# Centroid : (419, 441), farthest Point : (568, 719)
# Centroid : (379, 447), farthest Point : (543, 719)
# Centroid : (344, 452), farthest Point : (522, 718)
# Centroid : (319, 457), farthest Point : (548, 717)
# Centroid : (293, 451), farthest Point : (499, 716)
# Centroid : (288, 456), farthest Point : (500, 719)
# Centroid : (293, 457), farthest Point : (541, 714)
# Centroid : (306, 457), farthest Point : (551, 715)
# Centroid : (325, 451), farthest Point : (584, 714)
# Centroid : (359, 453), farthest Point : (594, 717)
# Centroid : (395, 444), farthest Point : (634, 716)
# Centroid : (423, 418), farthest Point : (583, 714)
# Centroid : (573, 469), farthest Point : (989, 715)
# Centroid : (587, 454), farthest Point : (805, 719)
# Centroid : (632, 453), farthest Point : (864, 719)
# Centroid : (654, 438), farthest Point : (801, 719)
# Centroid : (684, 424), farthest Point : (817, 719)
# Centroid : (706, 426), farthest Point : (834, 719)
# Centroid : (718, 416), farthest Point : (767, 719)
# Centroid : (724, 423), farthest Point : (755, 719)
# Centroid : (728, 427), farthest Point : (760, 719)
# Centroid : (720, 414), farthest Point : (732, 719)
# Centroid : (716, 420), farthest Point : (754, 719)
# Centroid : (708, 430), farthest Point : (827, 719)
# Centroid : (706, 421), farthest Point : (741, 719)
# Centroid : (705, 425), farthest Point : (732, 719)
# Centroid : (706, 422), farthest Point : (725, 719)
# Centroid : (707, 430), farthest Point : (654, 717)
# Centroid : (706, 432), farthest Point : (795, 719)
# Centroid : (698, 432), farthest Point : (807, 716)
# Centroid : (688, 434), farthest Point : (791, 719)
# Centroid : (669, 425), farthest Point : (706, 719)
# Centroid : (657, 441), farthest Point : (517, 171)
# Centroid : (640, 445), farthest Point : (472, 179)
# Centroid : (552, 413), farthest Point : (651, 719)
# Centroid : (584, 442), farthest Point : (945, 394)
# Centroid : (477, 408), farthest Point : (598, 719)
# Centroid : (440, 408), farthest Point : (582, 719)
# Centroid : (409, 410), farthest Point : (549, 718)
# Centroid : (384, 414), farthest Point : (546, 719)
# Centroid : (371, 423), farthest Point : (573, 719)
# Centroid : (362, 427), farthest Point : (599, 717)
# Centroid : (359, 430), farthest Point : (592, 719)
# Centroid : (358, 430), farthest Point : (581, 719)
# Centroid : (362, 435), farthest Point : (593, 710)
# Centroid : (369, 454), farthest Point : (602, 718)
# Centroid : (377, 466), farthest Point : (603, 719)
# Centroid : (379, 465), farthest Point : (223, 190)
# Centroid : (396, 471), farthest Point : (244, 191)
# Centroid : (414, 477), farthest Point : (250, 199)
# Centroid : (431, 483), farthest Point : (280, 199)
# Centroid : (441, 482), farthest Point : (304, 196)
# Centroid : (442, 481), farthest Point : (311, 202)
# Centroid : (452, 488), farthest Point : (319, 207)
# Centroid : (457, 495), farthest Point : (320, 210)
# Centroid : (454, 488), farthest Point : (325, 212)
# Centroid : (456, 489), farthest Point : (329, 213)
# Centroid : (460, 492), farthest Point : (335, 215)
# Centroid : (460, 488), farthest Point : (342, 215)
# Centroid : (463, 490), farthest Point : (340, 220)
# Centroid : (467, 492), farthest Point : (344, 220)
# Centroid : (466, 491), farthest Point : (339, 225)
# Centroid : (467, 491), farthest Point : (336, 229)
# Centroid : (466, 497), farthest Point : (329, 235)
# Centroid : (466, 502), farthest Point : (300, 261)
# Centroid : (473, 514), farthest Point : (309, 279)
# Centroid : (487, 529), farthest Point : (309, 309)
# Centroid : (508, 544), farthest Point : (341, 318)
# Centroid : (612, 549), farthest Point : (930, 397)
# Centroid : (641, 552), farthest Point : (922, 393)
# Centroid : (663, 549), farthest Point : (913, 384)
# Centroid : (687, 542), farthest Point : (954, 388)
# Centroid : (701, 533), farthest Point : (932, 389)
# Centroid : (706, 513), farthest Point : (567, 296)
# Centroid : (716, 504), farthest Point : (589, 276)
# Centroid : (715, 489), farthest Point : (584, 267)
# Centroid : (707, 496), farthest Point : (569, 258)
# Centroid : (706, 506), farthest Point : (554, 263)
# Centroid : (695, 507), farthest Point : (538, 263)
# Centroid : (682, 510), farthest Point : (517, 265)
# Centroid : (683, 514), farthest Point : (515, 264)
# Centroid : (684, 509), farthest Point : (511, 262)
# Centroid : (679, 509), farthest Point : (501, 259)
# Centroid : (682, 510), farthest Point : (972, 382)
# Centroid : (676, 509), farthest Point : (510, 256)
# Centroid : (682, 514), farthest Point : (505, 261)
# Centroid : (679, 515), farthest Point : (503, 263)
# Centroid : (681, 512), farthest Point : (502, 262)
# Centroid : (678, 516), farthest Point : (972, 382)
# Centroid : (666, 513), farthest Point : (488, 269)
# Centroid : (683, 531), farthest Point : (990, 715)
# Centroid : (662, 526), farthest Point : (472, 268)
# Centroid : (657, 523), farthest Point : (452, 280)
# Centroid : (650, 526), farthest Point : (435, 288)
# Centroid : (640, 530), farthest Point : (930, 383)
# Centroid : (626, 539), farthest Point : (389, 317)
# Centroid : (520, 541), farthest Point : (382, 319)
# Centroid : (505, 551), farthest Point : (354, 333)
# Centroid : (485, 557), farthest Point : (314, 351)
# Centroid : (466, 563), farthest Point : (306, 356)
# Centroid : (451, 568), farthest Point : (271, 375)
# Centroid : (439, 573), farthest Point : (254, 381)
# Centroid : (429, 573), farthest Point : (228, 396)
# Centroid : (422, 574), farthest Point : (218, 400)
# Centroid : (417, 575), farthest Point : (211, 403)
# Centroid : (415, 572), farthest Point : (219, 383)
# Centroid : (416, 561), farthest Point : (218, 366)
# Centroid : (422, 547), farthest Point : (220, 341)
# Centroid : (427, 528), farthest Point : (227, 312)
# Centroid : (425, 502), farthest Point : (238, 278)
# Centroid : (436, 488), farthest Point : (659, 716)
# Centroid : (444, 474), farthest Point : (659, 719)
# Centroid : (562, 506), farthest Point : (953, 719)
# Centroid : (435, 444), farthest Point : (581, 715)
# Centroid : (434, 439), farthest Point : (581, 719)
# Centroid : (439, 444), farthest Point : (591, 715)
# Centroid : (451, 457), farthest Point : (596, 716)
# Centroid : (459, 471), farthest Point : (298, 233)
# Centroid : (575, 527), farthest Point : (944, 701)
# Centroid : (570, 536), farthest Point : (320, 308)
# Centroid : (503, 538), farthest Point : (360, 328)
# Centroid : (608, 557), farthest Point : (941, 380)
# Centroid : (538, 567), farthest Point : (400, 360)
# Centroid : (552, 573), farthest Point : (410, 379)
# Centroid : (644, 574), farthest Point : (430, 396)
# Centroid : (641, 578), farthest Point : (430, 426)
# Centroid : (644, 585), farthest Point : (448, 432)
# Centroid : (647, 587), farthest Point : (448, 435)
# Centroid : (639, 586), farthest Point : (861, 397)
# Centroid : (615, 587), farthest Point : (855, 458)
# Centroid : (606, 578), farthest Point : (901, 398)
# Centroid : (466, 584), farthest Point : (299, 406)
# Centroid : (423, 579), farthest Point : (233, 405)
# Centroid : (375, 573), farthest Point : (175, 386)
# Centroid : (320, 574), farthest Point : (110, 390)
# Centroid : (295, 575), farthest Point : (74, 392)
# Centroid : (279, 579), farthest Point : (69, 383)
# Centroid : (290, 578), farthest Point : (60, 391)
# Centroid : (327, 565), farthest Point : (91, 375)
# Centroid : (373, 552), farthest Point : (149, 350)
# Centroid : (430, 538), farthest Point : (216, 331)
# Centroid : (581, 546), farthest Point : (974, 714)
# Centroid : (620, 525), farthest Point : (936, 386)
# Centroid : (658, 516), farthest Point : (464, 259)
# Centroid : (679, 512), farthest Point : (519, 253)
# Centroid : (689, 502), farthest Point : (531, 256)
# Centroid : (689, 506), farthest Point : (530, 261)
# Centroid : (684, 515), farthest Point : (538, 255)
# Centroid : (685, 511), farthest Point : (957, 364)
# Centroid : (676, 522), farthest Point : (953, 382)
# Centroid : (674, 528), farthest Point : (509, 288)
# Centroid : (664, 538), farthest Point : (502, 314)
# Centroid : (666, 546), farthest Point : (935, 369)
# Centroid : (662, 556), farthest Point : (943, 390)
# Centroid : (657, 564), farthest Point : (930, 374)
# Centroid : (646, 576), farthest Point : (931, 388)
# Centroid : (649, 596), farthest Point : (851, 440)
# Centroid : (668, 625), farthest Point : (822, 431)
# Centroid : (703, 667), farthest Point : (972, 713)
# Centroid : (781, 671), farthest Point : (969, 715)
# Centroid : (848, 461), farthest Point : (815, 602)
# Centroid : (768, 640), farthest Point : (837, 512)
# Centroid : (792, 595), farthest Point : (859, 450)
# Centroid : (805, 573), farthest Point : (709, 713)
# Centroid : (831, 526), farthest Point : (704, 708)
# Centroid : (839, 527), farthest Point : (725, 703)
# Centroid : (831, 515), farthest Point : (766, 719)
# Centroid : (819, 527), farthest Point : (779, 719)
# Centroid : (822, 526), farthest Point : (726, 717)
# Centroid : (789, 570), farthest Point : (785, 403)
# Centroid : (850, 484), farthest Point : (816, 653)
# Centroid : (844, 475), farthest Point : (820, 622)
# Centroid : (847, 474), farthest Point : (811, 616)
# Centroid : (762, 568), farthest Point : (954, 395)
# Centroid : (764, 572), farthest Point : (929, 372)
# Centroid : (774, 569), farthest Point : (957, 388)
# Centroid : (763, 572), farthest Point : (975, 382)
# Centroid : (751, 583), farthest Point : (941, 377)
# Centroid : (690, 645), farthest Point : (569, 537)
# Centroid : (682, 643), farthest Point : (844, 596)
# Centroid : (672, 642), farthest Point : (850, 615)
# Centroid : (674, 639), farthest Point : (554, 506)
# Centroid : (726, 583), farthest Point : (948, 407)
# Centroid : (693, 622), farthest Point : (849, 495)
# Centroid : (711, 606), farthest Point : (833, 442)
# Centroid : (746, 572), farthest Point : (972, 355)
# Centroid : (767, 579), farthest Point : (970, 361)
# Centroid : (803, 545), farthest Point : (927, 360)
# Centroid : (836, 490), farthest Point : (799, 640)
# Centroid : (840, 484), farthest Point : (800, 636)
# Centroid : (789, 564), farthest Point : (661, 717)
# Centroid : (829, 485), farthest Point : (766, 654)
# Centroid : (815, 542), farthest Point : (770, 657)
# Centroid : (790, 561), farthest Point : (692, 707)
# Centroid : (820, 537), farthest Point : (743, 719)
# Centroid : (793, 566), farthest Point : (693, 711)
# Centroid : (822, 522), farthest Point : (684, 709)
# Centroid : (833, 490), farthest Point : (776, 637)
# Centroid : (831, 479), farthest Point : (957, 380)
# Centroid : (834, 470), farthest Point : (776, 617)
# Centroid : (757, 577), farthest Point : (960, 375)
# Centroid : (741, 582), farthest Point : (930, 369)
# Centroid : (683, 613), farthest Point : (545, 434)
# Centroid : (670, 603), farthest Point : (504, 404)
# Centroid : (653, 598), farthest Point : (978, 714)
# Centroid : (631, 576), farthest Point : (436, 359)
# Centroid : (620, 570), farthest Point : (396, 356)
# Centroid : (618, 558), farthest Point : (958, 377)
# Centroid : (607, 553), farthest Point : (948, 397)
# Centroid : (608, 545), farthest Point : (908, 385)
# Centroid : (610, 535), farthest Point : (939, 360)
# Centroid : (539, 521), farthest Point : (368, 314)
# Centroid : (616, 518), farthest Point : (935, 382)
# Centroid : (628, 510), farthest Point : (941, 383)
# Centroid : (645, 501), farthest Point : (940, 374)
# Centroid : (662, 494), farthest Point : (450, 282)
# Centroid : (673, 489), farthest Point : (941, 373)
# Centroid : (680, 485), farthest Point : (938, 357)
# Centroid : (683, 486), farthest Point : (945, 362)
# Centroid : (676, 486), farthest Point : (507, 259)
# Centroid : (676, 485), farthest Point : (959, 353)
# Centroid : (670, 484), farthest Point : (962, 379)
# Centroid : (669, 485), farthest Point : (962, 379)
# Centroid : (669, 486), farthest Point : (979, 349)
# Centroid : (664, 487), farthest Point : (942, 391)
# Centroid : (665, 507), farthest Point : (933, 370)
# Centroid : (669, 521), farthest Point : (459, 308)
# Centroid : (672, 530), farthest Point : (461, 321)
# Centroid : (669, 535), farthest Point : (458, 323)
# Centroid : (667, 537), farthest Point : (450, 328)
# Centroid : (667, 537), farthest Point : (451, 325)
# Centroid : (666, 537), farthest Point : (445, 332)
# Centroid : (663, 535), farthest Point : (451, 326)
# Centroid : (660, 539), farthest Point : (449, 329)
# Centroid : (663, 541), farthest Point : (451, 328)
# Centroid : (656, 537), farthest Point : (446, 332)
# Centroid : (652, 537), farthest Point : (440, 336)
# Centroid : (652, 541), farthest Point : (445, 330)
# Centroid : (651, 543), farthest Point : (431, 341)
# Centroid : (641, 553), farthest Point : (419, 349)
# Centroid : (626, 554), farthest Point : (407, 357)
# Centroid : (620, 561), farthest Point : (386, 372)
# Centroid : (529, 563), farthest Point : (361, 382)
# Centroid : (518, 574), farthest Point : (346, 401)
# Centroid : (502, 581), farthest Point : (335, 411)
# Centroid : (490, 586), farthest Point : (310, 431)
# Centroid : (481, 591), farthest Point : (306, 444)
# Centroid : (473, 595), farthest Point : (298, 446)
# Centroid : (464, 589), farthest Point : (285, 441)
# Centroid : (457, 583), farthest Point : (275, 426)
# Centroid : (453, 573), farthest Point : (270, 406)
# Centroid : (451, 561), farthest Point : (261, 395)
# Centroid : (453, 547), farthest Point : (263, 369)
# Centroid : (453, 531), farthest Point : (261, 349)
# Centroid : (448, 517), farthest Point : (255, 332)
# Centroid : (444, 507), farthest Point : (257, 317)
# Centroid : (442, 507), farthest Point : (263, 304)
# Centroid : (446, 508), farthest Point : (273, 306)
# Centroid : (459, 516), farthest Point : (275, 315)
# Centroid : (588, 552), farthest Point : (973, 716)
# Centroid : (607, 563), farthest Point : (968, 709)
# Centroid : (523, 544), farthest Point : (365, 366)
# Centroid : (640, 573), farthest Point : (970, 708)
# Centroid : (643, 572), farthest Point : (430, 404)
# Centroid : (682, 583), farthest Point : (967, 719)
# Centroid : (672, 581), farthest Point : (497, 420)
# Centroid : (681, 583), farthest Point : (512, 437)
# Centroid : (687, 586), farthest Point : (522, 438)
# Centroid : (688, 586), farthest Point : (525, 437)
# Centroid : (685, 584), farthest Point : (510, 448)
# Centroid : (690, 577), farthest Point : (951, 400)
# Centroid : (681, 598), farthest Point : (917, 716)
# Centroid : (656, 589), farthest Point : (870, 469)
# Centroid : (635, 593), farthest Point : (874, 472)
# Centroid : (623, 588), farthest Point : (909, 392)
# Centroid : (502, 606), farthest Point : (351, 463)
# Centroid : (470, 608), farthest Point : (301, 478)
# Centroid : (439, 613), farthest Point : (257, 494)
# Centroid : (413, 617), farthest Point : (225, 510)
# Centroid : (401, 618), farthest Point : (216, 503)
# Centroid : (403, 614), farthest Point : (208, 494)
# Centroid : (421, 603), farthest Point : (231, 476)
# Centroid : (442, 590), farthest Point : (262, 444)
# Centroid : (467, 577), farthest Point : (278, 429)
# Centroid : (486, 553), farthest Point : (322, 385)
# Centroid : (576, 558), farthest Point : (360, 348)
# Centroid : (531, 519), farthest Point : (391, 322)
# Centroid : (550, 503), farthest Point : (410, 300)
# Centroid : (639, 524), farthest Point : (439, 279)
# Centroid : (657, 514), farthest Point : (434, 276)
# Centroid : (567, 481), farthest Point : (656, 719)
# Centroid : (563, 483), farthest Point : (658, 719)
# Centroid : (563, 485), farthest Point : (659, 719)
# Centroid : (664, 530), farthest Point : (967, 708)
# Centroid : (551, 501), farthest Point : (429, 297)
# Centroid : (651, 547), farthest Point : (976, 714)
# Centroid : (548, 523), farthest Point : (419, 323)
# Centroid : (627, 550), farthest Point : (405, 345)
# Centroid : (542, 544), farthest Point : (405, 360)
# Centroid : (620, 566), farthest Point : (401, 388)
# Centroid : (636, 584), farthest Point : (976, 715)
# Centroid : (533, 586), farthest Point : (678, 719)
# Centroid : (530, 594), farthest Point : (686, 715)
# Centroid : (521, 596), farthest Point : (376, 471)
# Centroid : (517, 592), farthest Point : (373, 444)
# Centroid : (507, 583), farthest Point : (351, 410)
# Centroid : (494, 577), farthest Point : (334, 402)
# Centroid : (485, 572), farthest Point : (311, 389)
# Centroid : (480, 570), farthest Point : (301, 379)
# Centroid : (474, 568), farthest Point : (295, 373)
# Centroid : (473, 565), farthest Point : (296, 366)
# Centroid : (477, 562), farthest Point : (296, 365)
# Centroid : (559, 573), farthest Point : (315, 355)
# Centroid : (580, 576), farthest Point : (894, 699)
# Centroid : (526, 550), farthest Point : (411, 328)
# Centroid : (606, 563), farthest Point : (454, 317)
# Centroid : (612, 562), farthest Point : (482, 315)
# Centroid : (622, 563), farthest Point : (483, 315)
# Centroid : (609, 561), farthest Point : (433, 330)
# Centroid : (611, 575), farthest Point : (976, 715)
# Centroid : (492, 570), farthest Point : (353, 373)
# Centroid : (478, 582), farthest Point : (294, 429)
# Centroid : (477, 585), farthest Point : (295, 435)
# Centroid : (480, 580), farthest Point : (314, 412)
# Centroid : (491, 567), farthest Point : (361, 351)
# Centroid : (505, 558), farthest Point : (372, 328)
# Centroid : (512, 553), farthest Point : (398, 305)
# Centroid : (516, 550), farthest Point : (401, 305)
# Centroid : (518, 554), farthest Point : (401, 311)
# Centroid : (516, 559), farthest Point : (407, 320)
# Centroid : (519, 565), farthest Point : (407, 334)
# Centroid : (526, 564), farthest Point : (402, 345)
# Centroid : (602, 560), farthest Point : (424, 312)
# Centroid : (601, 555), farthest Point : (429, 293)
# Centroid : (604, 562), farthest Point : (413, 330)
# Centroid : (614, 574), farthest Point : (815, 407)
# Centroid : (615, 568), farthest Point : (887, 400)
# Centroid : (610, 562), farthest Point : (409, 331)
# Centroid : (615, 561), farthest Point : (422, 305)
# Centroid : (625, 567), farthest Point : (418, 335)
# Centroid : (636, 578), farthest Point : (443, 422)
# Centroid : (639, 571), farthest Point : (460, 369)
# Centroid : (651, 570), farthest Point : (489, 340)
# Centroid : (673, 579), farthest Point : (973, 716)
# Centroid : (690, 583), farthest Point : (972, 716)
# Centroid : (676, 570), farthest Point : (837, 404)
# Centroid : (682, 574), farthest Point : (568, 371)
# Centroid : (698, 567), farthest Point : (595, 392)
# Centroid : (708, 561), farthest Point : (612, 380)
# Centroid : (716, 565), farthest Point : (626, 380)
# Centroid : (731, 574), farthest Point : (647, 389)
# Centroid : (733, 570), farthest Point : (673, 385)
# Centroid : (757, 591), farthest Point : (986, 715)
# Centroid : (764, 579), farthest Point : (976, 716)
# Centroid : (759, 558), farthest Point : (957, 384)
# Centroid : (762, 596), farthest Point : (989, 714)
# Centroid : (736, 570), farthest Point : (675, 384)
# Centroid : (746, 583), farthest Point : (975, 714)
# Centroid : (736, 592), farthest Point : (921, 707)
# Centroid : (736, 597), farthest Point : (987, 713)
# Centroid : (732, 580), farthest Point : (953, 719)
# Centroid : (715, 579), farthest Point : (609, 335)
# Centroid : (723, 573), farthest Point : (979, 716)
# Centroid : (744, 572), farthest Point : (976, 715)
# Centroid : (759, 577), farthest Point : (589, 441)
# Centroid : (772, 560), farthest Point : (937, 375)
# Centroid : (844, 468), farthest Point : (767, 575)
# Centroid : (818, 497), farthest Point : (834, 604)
# Centroid : (802, 563), farthest Point : (803, 401)
# Centroid : (834, 523), farthest Point : (749, 714)
# Centroid : (858, 478), farthest Point : (957, 398)
# Centroid : (857, 473), farthest Point : (828, 601)
# Centroid : (839, 506), farthest Point : (776, 719)
# Centroid : (876, 468), farthest Point : (976, 396)
# Centroid : (879, 489), farthest Point : (901, 382)
# Centroid : (1218, 653), farthest Point : (1252, 550)
# Centroid : (983, 509), farthest Point : (988, 402)
# Centroid : (1209, 670), farthest Point : (1279, 630)
# Centroid : (1089, 557), farthest Point : (1070, 433)
# Centroid : (522, 642), farthest Point : (331, 719)
# Centroid : (481, 594), farthest Point : (190, 719)
# Centroid : (476, 490), farthest Point : (107, 673)
# Centroid : (660, 339), farthest Point : (648, 551)
# Centroid : (664, 319), farthest Point : (656, 543)
# Centroid : (665, 333), farthest Point : (653, 551)
# Centroid : (713, 358), farthest Point : (1011, 451)
# Centroid : (647, 341), farthest Point : (616, 119)
# Centroid : (663, 261), farthest Point : (777, 426)
# Centroid : (629, 347), farthest Point : (582, 128)
# Centroid : (628, 353), farthest Point : (578, 140)
# Centroid : (614, 367), farthest Point : (575, 140)
# Centroid : (620, 374), farthest Point : (578, 149)
# Centroid : (624, 376), farthest Point : (544, 158)
# Centroid : (625, 376), farthest Point : (596, 151)
# Centroid : (636, 379), farthest Point : (594, 155)
# Centroid : (633, 413), farthest Point : (599, 183)
# Centroid : (624, 441), farthest Point : (580, 212)
# Centroid : (616, 434), farthest Point : (564, 214)
# Centroid : (593, 425), farthest Point : (570, 202)
# Centroid : (602, 420), farthest Point : (554, 198)
# Centroid : (584, 413), farthest Point : (323, 429)
# Centroid : (591, 426), farthest Point : (537, 203)
# Centroid : (627, 424), farthest Point : (899, 546)
# Centroid : (587, 417), farthest Point : (533, 207)
# Centroid : (591, 409), farthest Point : (564, 625)
# Centroid : (604, 429), farthest Point : (900, 555)
# Centroid : (618, 428), farthest Point : (902, 548)
# Centroid : (616, 431), farthest Point : (900, 558)
# Centroid : (579, 421), farthest Point : (529, 218)
# Centroid : (592, 419), farthest Point : (581, 630)
# Centroid : (580, 425), farthest Point : (394, 535)
# Centroid : (580, 424), farthest Point : (526, 220)
# Centroid : (581, 427), farthest Point : (572, 219)
# Centroid : (622, 438), farthest Point : (905, 571)
# Centroid : (585, 415), farthest Point : (584, 631)
# Centroid : (618, 430), farthest Point : (904, 582)
# Centroid : (588, 414), farthest Point : (382, 540)
# Centroid : (592, 415), farthest Point : (628, 204)
# Centroid : (669, 437), farthest Point : (947, 559)
# Centroid : (592, 418), farthest Point : (369, 538)
# Centroid : (659, 435), farthest Point : (904, 575)
# Centroid : (629, 432), farthest Point : (904, 567)
# Centroid : (641, 441), farthest Point : (905, 578)
# Centroid : (637, 438), farthest Point : (906, 581)
# Centroid : (621, 434), farthest Point : (905, 574)
# Centroid : (662, 443), farthest Point : (950, 564)
# Centroid : (632, 441), farthest Point : (906, 576)
# Centroid : (752, 507), farthest Point : (1266, 719)
# Centroid : (854, 501), farthest Point : (413, 360)
# Centroid : (1098, 498), farthest Point : (1054, 183)
# Centroid : (1117, 465), farthest Point : (1277, 128)
# Centroid : (1104, 461), farthest Point : (1275, 126)
# Centroid : (1102, 457), farthest Point : (1252, 149)
# Centroid : (1105, 452), farthest Point : (1267, 128)
# Centroid : (1098, 458), farthest Point : (1275, 150)
# Centroid : (1086, 476), farthest Point : (1014, 179)
# Centroid : (1073, 471), farthest Point : (1001, 178)
# Centroid : (616, 441), farthest Point : (900, 577)
# Centroid : (1072, 447), farthest Point : (1278, 174)
# Centroid : (1061, 477), farthest Point : (973, 189)
# Centroid : (1063, 470), farthest Point : (975, 191)
# Centroid : (1064, 487), farthest Point : (984, 188)
# Centroid : (1066, 485), farthest Point : (985, 189)
# Centroid : (1056, 477), farthest Point : (982, 188)
# Centroid : (1053, 478), farthest Point : (953, 194)
# Centroid : (608, 441), farthest Point : (902, 579)
# Centroid : (1045, 506), farthest Point : (931, 245)
# Centroid : (1046, 498), farthest Point : (1112, 719)
# Centroid : (1065, 504), farthest Point : (1145, 718)
# Centroid : (1068, 487), farthest Point : (1014, 719)
# Centroid : (1089, 456), farthest Point : (1279, 181)
# Centroid : (1079, 449), farthest Point : (1279, 175)
# Centroid : (1092, 409), farthest Point : (1233, 0)
# Centroid : (1062, 471), farthest Point : (996, 194)
# Centroid : (612, 443), farthest Point : (904, 575)
# Centroid : (1050, 472), farthest Point : (976, 196)
# Centroid : (1057, 469), farthest Point : (985, 193)
# Centroid : (608, 441), farthest Point : (874, 538)
# Centroid : (1066, 465), farthest Point : (1005, 184)
# Centroid : (1074, 469), farthest Point : (1010, 182)
# Centroid : (1087, 444), farthest Point : (1279, 121)
# Centroid : (1070, 460), farthest Point : (1017, 174)
# Centroid : (615, 448), farthest Point : (900, 575)
# Centroid : (1072, 450), farthest Point : (1029, 170)
# Centroid : (1096, 390), farthest Point : (1060, 0)
# Centroid : (1090, 439), farthest Point : (1266, 165)
# Centroid : (1092, 420), farthest Point : (1240, 149)
# Centroid : (1097, 427), farthest Point : (1279, 181)
# Centroid : (1101, 407), farthest Point : (1279, 175)
# Centroid : (611, 443), farthest Point : (892, 568)
# Centroid : (614, 444), farthest Point : (892, 514)
# Centroid : (614, 447), farthest Point : (917, 543)
# Centroid : (609, 445), farthest Point : (903, 526)
# Centroid : (1128, 411), farthest Point : (1211, 719)
# Centroid : (1126, 398), farthest Point : (1271, 177)
# Centroid : (1124, 408), farthest Point : (1243, 151)
# Centroid : (1113, 407), farthest Point : (1101, 153)
# Centroid : (1109, 414), farthest Point : (1277, 148)
# Centroid : (1096, 414), farthest Point : (1066, 161)
# Centroid : (1088, 422), farthest Point : (1050, 167)
# Centroid : (1074, 457), farthest Point : (1037, 170)
# Centroid : (1093, 405), farthest Point : (1279, 128)
# Centroid : (1070, 438), farthest Point : (1000, 178)
# Centroid : (1051, 468), farthest Point : (982, 184)
# Centroid : (1030, 468), farthest Point : (953, 196)
# Centroid : (605, 443), farthest Point : (850, 546)
# Centroid : (978, 485), farthest Point : (918, 206)
# Centroid : (764, 465), farthest Point : (1142, 715)
# Centroid : (770, 473), farthest Point : (1129, 709)
# Centroid : (753, 474), farthest Point : (1059, 719)
# Centroid : (766, 479), farthest Point : (1118, 713)
# Centroid : (768, 480), farthest Point : (1116, 716)
# Centroid : (773, 477), farthest Point : (390, 538)
# Centroid : (567, 432), farthest Point : (326, 432)
# Centroid : (757, 465), farthest Point : (1048, 719)
# Centroid : (574, 435), farthest Point : (385, 542)
# Centroid : (758, 458), farthest Point : (1086, 716)
# Centroid : (745, 450), farthest Point : (1081, 591)
# Centroid : (739, 454), farthest Point : (1098, 628)
# Centroid : (762, 461), farthest Point : (1058, 709)
# Centroid : (735, 448), farthest Point : (385, 539)
# Centroid : (721, 448), farthest Point : (380, 539)
# Centroid : (726, 450), farthest Point : (1096, 595)
# Centroid : (702, 448), farthest Point : (338, 541)
# Centroid : (699, 447), farthest Point : (1033, 576)
# Centroid : (699, 448), farthest Point : (395, 537)
# Centroid : (706, 447), farthest Point : (1036, 485)
# Centroid : (705, 467), farthest Point : (1000, 719)
# Centroid : (666, 450), farthest Point : (949, 593)
# Centroid : (647, 446), farthest Point : (932, 591)
# Centroid : (654, 456), farthest Point : (921, 634)
# Centroid : (670, 484), farthest Point : (1020, 719)
# Centroid : (654, 476), farthest Point : (942, 719)
# Centroid : (672, 488), farthest Point : (1026, 715)
# Centroid : (660, 484), farthest Point : (1021, 715)
# Centroid : (651, 476), farthest Point : (1024, 714)
# Centroid : (676, 487), farthest Point : (1013, 716)
# Centroid : (674, 489), farthest Point : (1020, 718)
# Centroid : (662, 486), farthest Point : (1016, 719)
# Centroid : (653, 477), farthest Point : (1030, 715)
# Centroid : (661, 484), farthest Point : (1016, 711)
# Centroid : (659, 482), farthest Point : (1013, 716)
# Centroid : (647, 477), farthest Point : (940, 719)
# Centroid : (647, 481), farthest Point : (1008, 719)
# Centroid : (655, 481), farthest Point : (1011, 709)
# Centroid : (663, 485), farthest Point : (1009, 710)
# Centroid : (667, 485), farthest Point : (1022, 714)
# Centroid : (665, 487), farthest Point : (1013, 713)
# Centroid : (662, 492), farthest Point : (1015, 715)
# Centroid : (692, 493), farthest Point : (1021, 718)
# Centroid : (709, 496), farthest Point : (1012, 719)
# Centroid : (679, 491), farthest Point : (1046, 659)
# Centroid : (650, 476), farthest Point : (953, 712)
# Centroid : (691, 496), farthest Point : (1010, 719)
# Centroid : (675, 493), farthest Point : (1014, 715)
# Centroid : (679, 497), farthest Point : (1052, 645)
# Centroid : (694, 497), farthest Point : (1051, 654)
# Centroid : (682, 495), farthest Point : (1014, 719)
# Centroid : (669, 493), farthest Point : (1012, 715)
# Centroid : (672, 487), farthest Point : (1011, 719)
# Centroid : (665, 486), farthest Point : (1012, 715)
# Centroid : (676, 499), farthest Point : (1012, 714)
# Centroid : (702, 496), farthest Point : (1001, 719)
# Centroid : (665, 487), farthest Point : (1002, 713)
# Centroid : (662, 485), farthest Point : (1003, 714)
# Centroid : (666, 487), farthest Point : (1009, 711)
# Centroid : (667, 488), farthest Point : (1007, 717)
# Centroid : (673, 494), farthest Point : (1009, 715)
# Centroid : (667, 488), farthest Point : (1008, 714)
# Centroid : (671, 488), farthest Point : (1012, 717)
# Centroid : (671, 487), farthest Point : (1012, 717)
# Centroid : (671, 493), farthest Point : (1014, 718)
# Centroid : (698, 497), farthest Point : (1019, 716)
# Centroid : (664, 490), farthest Point : (1026, 716)
# Centroid : (668, 490), farthest Point : (1030, 715)
# Centroid : (725, 504), farthest Point : (1035, 719)
# Centroid : (689, 493), farthest Point : (948, 717)
# Centroid : (659, 484), farthest Point : (978, 681)
# Centroid : (669, 494), farthest Point : (1006, 713)
# Centroid : (667, 492), farthest Point : (1010, 711)
# Centroid : (665, 487), farthest Point : (1012, 711)
# Centroid : (672, 495), farthest Point : (1019, 710)
# Centroid : (675, 489), farthest Point : (1035, 719)
# Centroid : (687, 488), farthest Point : (1065, 711)
# Centroid : (621, 442), farthest Point : (946, 494)
# Centroid : (703, 445), farthest Point : (1038, 482)
# Centroid : (581, 430), farthest Point : (581, 627)
# Centroid : (714, 444), farthest Point : (1039, 475)
# Centroid : (718, 444), farthest Point : (1038, 541)
# Centroid : (730, 445), farthest Point : (1054, 541)
# Centroid : (740, 442), farthest Point : (1069, 528)
# Centroid : (609, 444), farthest Point : (861, 544)
# Centroid : (589, 442), farthest Point : (391, 540)
# Centroid : (579, 434), farthest Point : (530, 244)
# Centroid : (608, 443), farthest Point : (905, 582)
# Centroid : (610, 447), farthest Point : (924, 567)
# Centroid : (609, 449), farthest Point : (905, 583)
# Centroid : (609, 446), farthest Point : (905, 581)
# Centroid : (615, 445), farthest Point : (905, 580)
# Centroid : (608, 448), farthest Point : (901, 583)
# Centroid : (607, 445), farthest Point : (904, 582)
# Centroid : (595, 443), farthest Point : (868, 540)
# Centroid : (576, 432), farthest Point : (403, 539)
# Centroid : (567, 432), farthest Point : (332, 437)
# Centroid : (747, 444), farthest Point : (1101, 541)
# Centroid : (751, 447), farthest Point : (347, 541)
# Centroid : (754, 470), farthest Point : (1119, 714)
# Centroid : (758, 497), farthest Point : (1090, 719)
# Centroid : (610, 430), farthest Point : (861, 538)
# Centroid : (615, 434), farthest Point : (896, 528)
# Centroid : (612, 433), farthest Point : (903, 580)
# Centroid : (606, 432), farthest Point : (903, 585)
# Centroid : (633, 429), farthest Point : (899, 582)
# Centroid : (598, 430), farthest Point : (896, 576)
# Centroid : (576, 417), farthest Point : (362, 539)
# Centroid : (609, 430), farthest Point : (901, 580)
# Centroid : (586, 420), farthest Point : (392, 536)
# Centroid : (614, 431), farthest Point : (904, 582)
# Centroid : (634, 425), farthest Point : (881, 507)
# Centroid : (640, 428), farthest Point : (903, 583)
# Centroid : (618, 431), farthest Point : (902, 580)
# Centroid : (611, 431), farthest Point : (902, 582)
# Centroid : (636, 433), farthest Point : (903, 584)
# Centroid : (637, 432), farthest Point : (904, 583)
# Centroid : (603, 411), farthest Point : (528, 213)
# Centroid : (613, 430), farthest Point : (904, 584)
# Centroid : (592, 412), farthest Point : (584, 629)
# Centroid : (596, 432), farthest Point : (885, 537)
# Centroid : (625, 433), farthest Point : (901, 581)
# Centroid : (622, 428), farthest Point : (904, 577)
# Centroid : (589, 410), farthest Point : (587, 630)
# Centroid : (586, 413), farthest Point : (591, 626)
# Centroid : (576, 415), farthest Point : (402, 539)
# Centroid : (589, 424), farthest Point : (393, 539)
# Centroid : (592, 423), farthest Point : (383, 541)
# Centroid : (619, 441), farthest Point : (905, 576)
# Centroid : (608, 416), farthest Point : (570, 622)
# Centroid : (628, 439), farthest Point : (903, 585)
# Centroid : (615, 436), farthest Point : (907, 577)
# Centroid : (642, 440), farthest Point : (902, 584)
# Centroid : (636, 444), farthest Point : (902, 585)
# Centroid : (638, 441), farthest Point : (905, 580)
# Centroid : (616, 442), farthest Point : (905, 566)
# Centroid : (648, 438), farthest Point : (900, 583)
# Centroid : (646, 441), farthest Point : (901, 583)
# Centroid : (630, 445), farthest Point : (901, 583)
# Centroid : (648, 445), farthest Point : (901, 581)
# Centroid : (614, 440), farthest Point : (901, 580)
# Centroid : (606, 440), farthest Point : (903, 573)
# Centroid : (623, 448), farthest Point : (903, 585)
# Centroid : (574, 427), farthest Point : (542, 227)
# Centroid : (583, 435), farthest Point : (532, 229)
# Centroid : (579, 433), farthest Point : (541, 225)
# Centroid : (576, 427), farthest Point : (380, 549)
# Centroid : (581, 424), farthest Point : (585, 625)
# Centroid : (607, 444), farthest Point : (905, 581)
# Centroid : (579, 429), farthest Point : (534, 232)
# Centroid : (573, 433), farthest Point : (390, 544)
# Centroid : (570, 437), farthest Point : (536, 238)
# Centroid : (621, 446), farthest Point : (900, 570)
# Centroid : (567, 434), farthest Point : (379, 543)
# Centroid : (576, 431), farthest Point : (583, 632)
# Centroid : (579, 432), farthest Point : (531, 237)
# Centroid : (581, 438), farthest Point : (375, 544)
# Centroid : (607, 448), farthest Point : (903, 578)
# Centroid : (565, 446), farthest Point : (252, 560)
# Centroid : (589, 435), farthest Point : (531, 236)
# Centroid : (583, 439), farthest Point : (381, 545)
# Centroid : (626, 445), farthest Point : (861, 542)
# Centroid : (575, 433), farthest Point : (384, 547)
# Centroid : (571, 434), farthest Point : (542, 229)
# Centroid : (632, 448), farthest Point : (901, 572)
# Centroid : (607, 445), farthest Point : (898, 581)
# Centroid : (575, 433), farthest Point : (581, 235)
# Centroid : (573, 434), farthest Point : (580, 237)
# Centroid : (596, 434), farthest Point : (582, 235)
# Centroid : (570, 434), farthest Point : (598, 236)
# Centroid : (572, 430), farthest Point : (584, 627)
# Centroid : (615, 440), farthest Point : (902, 579)
# Centroid : (570, 434), farthest Point : (382, 544)
# Centroid : (583, 427), farthest Point : (585, 623)
# Centroid : (585, 430), farthest Point : (582, 627)
# Centroid : (570, 432), farthest Point : (381, 547)
# Centroid : (595, 433), farthest Point : (576, 235)
# Centroid : (602, 445), farthest Point : (900, 582)
# Centroid : (619, 443), farthest Point : (905, 582)
# Centroid : (581, 429), farthest Point : (582, 627)
# Centroid : (595, 436), farthest Point : (578, 236)
# Centroid : (568, 435), farthest Point : (578, 236)
# Centroid : (597, 438), farthest Point : (581, 235)
# Centroid : (606, 448), farthest Point : (898, 581)
# Centroid : (635, 453), farthest Point : (902, 584)
# Centroid : (630, 449), farthest Point : (903, 574)
# Centroid : (622, 447), farthest Point : (901, 578)
# Centroid : (582, 432), farthest Point : (584, 633)
# Centroid : (583, 430), farthest Point : (581, 629)
# Centroid : (574, 432), farthest Point : (579, 235)
# Centroid : (597, 437), farthest Point : (575, 236)
# Centroid : (597, 438), farthest Point : (588, 238)
# Centroid : (582, 430), farthest Point : (581, 631)
# Centroid : (593, 436), farthest Point : (580, 237)
# Centroid : (597, 436), farthest Point : (575, 236)
# Centroid : (576, 431), farthest Point : (339, 447)
# Centroid : (576, 433), farthest Point : (578, 236)
# Centroid : (569, 436), farthest Point : (576, 236)
# Centroid : (596, 434), farthest Point : (577, 236)
# Centroid : (573, 438), farthest Point : (599, 242)
# Centroid : (596, 437), farthest Point : (582, 240)
# Centroid : (594, 432), farthest Point : (579, 236)
# Centroid : (583, 430), farthest Point : (578, 625)
# Centroid : (596, 434), farthest Point : (583, 236)
# Centroid : (612, 439), farthest Point : (854, 545)
# Centroid : (595, 436), farthest Point : (580, 238)
# Centroid : (628, 446), farthest Point : (862, 548)
# Centroid : (595, 437), farthest Point : (577, 238)
# Centroid : (594, 435), farthest Point : (577, 238)
# Centroid : (573, 430), farthest Point : (579, 235)
# Centroid : (595, 435), farthest Point : (576, 238)
# Centroid : (571, 434), farthest Point : (578, 235)
# Centroid : (574, 435), farthest Point : (579, 234)
# Centroid : (600, 445), farthest Point : (856, 551)
# Centroid : (630, 447), farthest Point : (898, 566)
# Centroid : (575, 434), farthest Point : (574, 237)
# Centroid : (605, 438), farthest Point : (583, 241)
# Centroid : (592, 441), farthest Point : (578, 237)
# Centroid : (578, 437), farthest Point : (596, 637)
# Centroid : (583, 435), farthest Point : (411, 537)
# Centroid : (605, 432), farthest Point : (548, 238)
# Centroid : (594, 427), farthest Point : (576, 220)
# Centroid : (570, 423), farthest Point : (574, 218)
# Centroid : (598, 423), farthest Point : (562, 213)
# Centroid : (626, 442), farthest Point : (851, 534)
# Centroid : (628, 449), farthest Point : (857, 550)
# Centroid : (640, 465), farthest Point : (880, 571)
# Centroid : (625, 479), farthest Point : (391, 576)
# Centroid : (606, 492), farthest Point : (625, 713)
# Centroid : (662, 567), farthest Point : (915, 683)
# Centroid : (567, 608), farthest Point : (97, 665)
# Centroid : (560, 604), farthest Point : (102, 719)
# Centroid : (534, 606), farthest Point : (98, 719)
# Centroid : (539, 605), farthest Point : (101, 719)
# Centroid : (538, 605), farthest Point : (100, 719)
# Centroid : (540, 610), farthest Point : (84, 669)
# Centroid : (539, 614), farthest Point : (98, 679)
# Centroid : (528, 619), farthest Point : (80, 693)
# Centroid : (544, 619), farthest Point : (109, 691)
# Centroid : (525, 617), farthest Point : (960, 683)
# Centroid : (631, 595), farthest Point : (900, 719)
# Centroid : (508, 620), farthest Point : (113, 719)
# Centroid : (502, 620), farthest Point : (908, 716)
# Centroid : (519, 621), farthest Point : (954, 704)
# Centroid : (515, 617), farthest Point : (939, 703)
# Centroid : (628, 598), farthest Point : (953, 685)
# Centroid : (524, 617), farthest Point : (950, 689)
# Centroid : (527, 617), farthest Point : (950, 688)
# Centroid : (514, 614), farthest Point : (948, 671)
# Centroid : (512, 616), farthest Point : (72, 688)
# Centroid : (531, 616), farthest Point : (90, 688)
# Centroid : (508, 612), farthest Point : (79, 688)
# Centroid : (519, 610), farthest Point : (54, 689)
# Centroid : (513, 607), farthest Point : (63, 719)
# Centroid : (617, 588), farthest Point : (914, 703)
# Centroid : (400, 567), farthest Point : (944, 683)
# Centroid : (414, 558), farthest Point : (947, 683)
# Centroid : (432, 574), farthest Point : (945, 685)
# Centroid : (441, 573), farthest Point : (946, 683)
# Centroid : (473, 594), farthest Point : (950, 671)
# Centroid : (478, 595), farthest Point : (951, 680)
# Centroid : (483, 600), farthest Point : (946, 678)
# Centroid : (491, 604), farthest Point : (947, 680)
# Centroid : (493, 605), farthest Point : (945, 686)
# Centroid : (488, 605), farthest Point : (914, 719)
# Centroid : (454, 603), farthest Point : (81, 686)
# Centroid : (498, 612), farthest Point : (946, 683)
# Centroid : (458, 605), farthest Point : (79, 686)
# Centroid : (486, 611), farthest Point : (916, 716)
# Centroid : (475, 609), farthest Point : (78, 687)
# Centroid : (461, 609), farthest Point : (85, 684)
# Centroid : (507, 620), farthest Point : (949, 661)
# Centroid : (461, 610), farthest Point : (83, 681)
# Centroid : (461, 612), farthest Point : (89, 684)
# Centroid : (475, 613), farthest Point : (65, 686)
# Centroid : (476, 613), farthest Point : (103, 719)
# Centroid : (479, 612), farthest Point : (99, 697)
# Centroid : (465, 611), farthest Point : (101, 696)
# Centroid : (461, 609), farthest Point : (105, 719)
# Centroid : (463, 611), farthest Point : (78, 686)
# Centroid : (462, 612), farthest Point : (83, 685)
# Centroid : (460, 612), farthest Point : (88, 681)
# Centroid : (458, 613), farthest Point : (77, 683)
# Centroid : (455, 611), farthest Point : (73, 686)
# Centroid : (494, 618), farthest Point : (951, 671)
# Centroid : (456, 610), farthest Point : (105, 719)
# Centroid : (454, 609), farthest Point : (74, 684)
# Centroid : (452, 610), farthest Point : (94, 719)
# Centroid : (499, 617), farthest Point : (947, 681)
# Centroid : (450, 609), farthest Point : (61, 687)
# Centroid : (455, 607), farthest Point : (83, 686)
# Centroid : (493, 616), farthest Point : (946, 677)
# Centroid : (451, 608), farthest Point : (69, 686)
# Centroid : (455, 609), farthest Point : (89, 678)
# Centroid : (491, 616), farthest Point : (946, 686)
# Centroid : (456, 609), farthest Point : (88, 684)
# Centroid : (454, 611), farthest Point : (75, 688)
# Centroid : (454, 608), farthest Point : (86, 686)
# Centroid : (452, 607), farthest Point : (87, 685)
# Centroid : (486, 615), farthest Point : (915, 706)
# Centroid : (455, 608), farthest Point : (86, 687)
# Centroid : (493, 617), farthest Point : (944, 681)
# Centroid : (493, 617), farthest Point : (945, 683)
# Centroid : (459, 608), farthest Point : (88, 678)
# Centroid : (451, 608), farthest Point : (76, 688)
# Centroid : (494, 617), farthest Point : (942, 677)
# Centroid : (488, 617), farthest Point : (948, 667)
# Centroid : (450, 609), farthest Point : (76, 688)
# Centroid : (447, 612), farthest Point : (62, 688)
# Centroid : (449, 608), farthest Point : (67, 682)
# Centroid : (446, 608), farthest Point : (64, 688)
# Centroid : (453, 609), farthest Point : (81, 688)
# Centroid : (492, 617), farthest Point : (944, 683)
# Centroid : (500, 617), farthest Point : (949, 666)
# Centroid : (492, 615), farthest Point : (947, 678)
# Centroid : (456, 605), farthest Point : (64, 686)
# Centroid : (448, 608), farthest Point : (78, 689)
# Centroid : (494, 614), farthest Point : (945, 688)
# Centroid : (453, 606), farthest Point : (106, 719)
# Centroid : (492, 615), farthest Point : (945, 666)
# Centroid : (498, 613), farthest Point : (944, 684)
# Centroid : (458, 604), farthest Point : (66, 687)
# Centroid : (455, 608), farthest Point : (69, 684)
# Centroid : (458, 605), farthest Point : (83, 683)
# Centroid : (496, 614), farthest Point : (946, 673)
# Centroid : (458, 607), farthest Point : (74, 685)
# Centroid : (458, 606), farthest Point : (79, 686)
# Centroid : (488, 613), farthest Point : (914, 706)
# Centroid : (455, 606), farthest Point : (95, 683)
# Centroid : (499, 615), farthest Point : (943, 681)
# Centroid : (453, 604), farthest Point : (74, 685)
# Centroid : (521, 610), farthest Point : (945, 678)
# Centroid : (454, 607), farthest Point : (88, 680)
# Centroid : (497, 615), farthest Point : (946, 684)
# Centroid : (456, 608), farthest Point : (80, 685)
# Centroid : (486, 600), farthest Point : (158, 536)
# Centroid : (501, 616), farthest Point : (949, 682)
# Centroid : (456, 605), farthest Point : (75, 689)
# Centroid : (499, 615), farthest Point : (951, 681)
# Centroid : (459, 606), farthest Point : (81, 691)
# Centroid : (456, 607), farthest Point : (104, 719)
# Centroid : (457, 607), farthest Point : (102, 719)
# Centroid : (455, 606), farthest Point : (62, 687)
# Centroid : (455, 607), farthest Point : (88, 719)
# Centroid : (458, 607), farthest Point : (106, 719)
# Centroid : (493, 616), farthest Point : (945, 683)
# Centroid : (496, 615), farthest Point : (948, 664)
# Centroid : (495, 617), farthest Point : (944, 661)
# Centroid : (457, 607), farthest Point : (88, 719)
# Centroid : (458, 606), farthest Point : (85, 719)
# Centroid : (455, 608), farthest Point : (93, 719)
# Centroid : (491, 617), farthest Point : (946, 675)
# Centroid : (492, 618), farthest Point : (943, 660)
# Centroid : (499, 617), farthest Point : (948, 680)
# Centroid : (489, 599), farthest Point : (153, 537)
# Centroid : (526, 611), farthest Point : (947, 683)
# Centroid : (491, 599), farthest Point : (156, 547)
# Centroid : (449, 604), farthest Point : (100, 719)
# Centroid : (445, 601), farthest Point : (102, 719)
# Centroid : (438, 599), farthest Point : (106, 719)
# Centroid : (491, 614), farthest Point : (950, 685)
# Centroid : (462, 612), farthest Point : (65, 719)
# Centroid : (510, 620), farthest Point : (946, 682)
# Centroid : (510, 618), farthest Point : (950, 670)
# Centroid : (510, 616), farthest Point : (944, 674)
# Centroid : (503, 618), farthest Point : (945, 670)
# Centroid : (469, 610), farthest Point : (81, 686)
# Centroid : (510, 619), farthest Point : (950, 680)
# Centroid : (505, 616), farthest Point : (951, 654)
# Centroid : (472, 605), farthest Point : (107, 719)
# Centroid : (524, 618), farthest Point : (103, 698)
# Centroid : (503, 615), farthest Point : (947, 662)
# Centroid : (504, 616), farthest Point : (947, 675)
# Centroid : (509, 618), farthest Point : (943, 684)
# Centroid : (466, 608), farthest Point : (87, 686)
# Centroid : (508, 617), farthest Point : (946, 679)
# Centroid : (467, 609), farthest Point : (95, 689)
# Centroid : (480, 612), farthest Point : (82, 676)
# Centroid : (461, 611), farthest Point : (52, 684)
# Centroid : (508, 614), farthest Point : (944, 683)
# Centroid : (521, 618), farthest Point : (947, 683)
# Centroid : (469, 608), farthest Point : (101, 719)
# Centroid : (466, 608), farthest Point : (95, 693)
# Centroid : (496, 618), farthest Point : (949, 682)
# Centroid : (464, 609), farthest Point : (71, 683)
# Centroid : (577, 578), farthest Point : (692, 719)
# Centroid : (506, 619), farthest Point : (951, 671)
# Centroid : (456, 610), farthest Point : (84, 685)
# Centroid : (501, 618), farthest Point : (946, 683)
# Centroid : (457, 610), farthest Point : (74, 687)
# Centroid : (574, 580), farthest Point : (427, 719)
# Centroid : (458, 611), farthest Point : (72, 687)
# Centroid : (502, 619), farthest Point : (948, 673)
# Centroid : (507, 618), farthest Point : (78, 687)
# Centroid : (462, 608), farthest Point : (74, 690)
# Centroid : (477, 608), farthest Point : (83, 691)
# Centroid : (506, 615), farthest Point : (946, 681)
# Centroid : (509, 612), farthest Point : (945, 676)
# Centroid : (515, 613), farthest Point : (82, 685)
# Centroid : (513, 611), farthest Point : (950, 683)
# Centroid : (526, 614), farthest Point : (72, 687)
# Centroid : (512, 613), farthest Point : (945, 682)
# Centroid : (510, 612), farthest Point : (946, 679)
# Centroid : (522, 616), farthest Point : (86, 684)
# Centroid : (524, 615), farthest Point : (74, 686)
# Centroid : (513, 614), farthest Point : (75, 684)
# Centroid : (512, 615), farthest Point : (73, 686)
# Centroid : (513, 614), farthest Point : (76, 685)
# Centroid : (523, 616), farthest Point : (80, 685)
# Centroid : (510, 613), farthest Point : (944, 687)
# Centroid : (515, 614), farthest Point : (946, 678)
# Centroid : (523, 617), farthest Point : (87, 681)
# Centroid : (524, 617), farthest Point : (87, 682)
# Centroid : (526, 618), farthest Point : (92, 681)
# Centroid : (471, 608), farthest Point : (102, 719)
# Centroid : (464, 608), farthest Point : (78, 686)
# Centroid : (463, 608), farthest Point : (90, 680)
# Centroid : (466, 609), farthest Point : (103, 719)
# Centroid : (461, 608), farthest Point : (105, 719)
# Centroid : (465, 610), farthest Point : (86, 685)
# Centroid : (463, 610), farthest Point : (107, 719)
# Centroid : (463, 611), farthest Point : (100, 719)
# Centroid : (465, 609), farthest Point : (102, 719)
# Centroid : (496, 616), farthest Point : (914, 705)
# Centroid : (511, 617), farthest Point : (948, 678)
# Centroid : (510, 618), farthest Point : (947, 677)
# Centroid : (479, 612), farthest Point : (78, 687)
# Centroid : (473, 611), farthest Point : (79, 688)
# Centroid : (464, 610), farthest Point : (84, 682)
# Centroid : (466, 610), farthest Point : (77, 686)
# ...
# Centroid : (516, 618), farthest Point : (74, 688)
# Centroid : (506, 617), farthest Point : (947, 661)
# Centroid : (508, 619), farthest Point : (81, 688)
# Centroid : (510, 617), farthest Point : (914, 719)
# Centroid : (518, 618), farthest Point : (943, 678)
# Centroid : (515, 618), farthest Point : (948, 670)
# Centroid : (510, 617), farthest Point : (97, 691)
# Centroid : (505, 614), farthest Point : (948, 677)
# Centroid : (509, 616), farthest Point : (93, 677)
# Centroid : (506, 618), farthest Point : (82, 683)
# Centroid : (516, 619), farthest Point : (81, 682)
# Centroid : (508, 615), farthest Point : (950, 678)
# Centroid : (514, 619), farthest Point : (948, 664)
# Centroid : (503, 618), farthest Point : (946, 664)
# Centroid : (500, 616), farthest Point : (945, 679)
# Centroid : (466, 606), farthest Point : (100, 719)
# Centroid : (513, 617), farthest Point : (101, 719)
# Centroid : (510, 614), farthest Point : (947, 676)
# Centroid : (616, 597), farthest Point : (950, 678)
# Centroid : (465, 605), farthest Point : (103, 719)
# Centroid : (505, 613), farthest Point : (949, 663)
# Centroid : (466, 603), farthest Point : (104, 719)
# Centroid : (498, 613), farthest Point : (914, 719)
# Centroid : (499, 614), farthest Point : (915, 716)
# Centroid : (510, 615), farthest Point : (945, 661)
# Centroid : (504, 615), farthest Point : (948, 678)
# Centroid : (506, 616), farthest Point : (948, 675)
# Centroid : (503, 615), farthest Point : (945, 678)
# Centroid : (514, 621), farthest Point : (947, 678)
# Centroid : (464, 610), farthest Point : (101, 719)
# Centroid : (494, 615), farthest Point : (915, 711)
# Centroid : (505, 616), farthest Point : (950, 678)
# Centroid : (509, 621), farthest Point : (80, 686)
# Centroid : (508, 617), farthest Point : (83, 684)
# Centroid : (497, 615), farthest Point : (915, 708)
# Centroid : (506, 619), farthest Point : (82, 682)
# Centroid : (515, 617), farthest Point : (945, 671)
# Centroid : (502, 617), farthest Point : (941, 682)
# Centroid : (497, 618), farthest Point : (944, 662)
# Centroid : (497, 615), farthest Point : (914, 719)
# Centroid : (505, 620), farthest Point : (80, 685)
# Centroid : (511, 616), farthest Point : (77, 685)
# Centroid : (510, 618), farthest Point : (76, 685)
# Centroid : (495, 614), farthest Point : (914, 719)
# Centroid : (497, 616), farthest Point : (938, 655)
# Centroid : (467, 607), farthest Point : (97, 719)
# Centroid : (506, 616), farthest Point : (943, 673)
# Centroid : (500, 618), farthest Point : (946, 674)
# Centroid : (501, 618), farthest Point : (945, 665)
# Centroid : (505, 615), farthest Point : (942, 680)
# Centroid : (496, 617), farthest Point : (914, 709)
# Centroid : (514, 621), farthest Point : (91, 677)
# Centroid : (491, 616), farthest Point : (922, 717)
# Centroid : (464, 608), farthest Point : (85, 683)
# Centroid : (497, 618), farthest Point : (935, 714)
# Centroid : (500, 618), farthest Point : (933, 703)
# Centroid : (465, 610), farthest Point : (86, 719)
# Centroid : (498, 618), farthest Point : (925, 692)
# Centroid : (497, 616), farthest Point : (912, 713)
# Centroid : (493, 615), farthest Point : (913, 719)
# Centroid : (508, 618), farthest Point : (84, 683)
# Centroid : (500, 616), farthest Point : (82, 684)
# Centroid : (494, 613), farthest Point : (70, 687)
# Centroid : (489, 615), farthest Point : (78, 688)
# Centroid : (510, 618), farthest Point : (101, 719)
# Centroid : (503, 615), farthest Point : (85, 680)
# Centroid : (492, 614), farthest Point : (79, 685)
# Centroid : (603, 591), farthest Point : (856, 718)
# Centroid : (600, 589), farthest Point : (840, 711)
# Centroid : (486, 607), farthest Point : (100, 719)
# Centroid : (493, 611), farthest Point : (105, 719)
# Centroid : (596, 588), farthest Point : (799, 718)
# Centroid : (486, 607), farthest Point : (99, 719)
# Centroid : (485, 606), farthest Point : (81, 684)
# Centroid : (584, 584), farthest Point : (750, 696)
# Centroid : (486, 604), farthest Point : (89, 685)
# Centroid : (476, 602), farthest Point : (83, 684)
# Centroid : (465, 604), farthest Point : (86, 686)
# Centroid : (460, 608), farthest Point : (106, 719)
# Centroid : (461, 609), farthest Point : (94, 684)
# Centroid : (512, 618), farthest Point : (930, 688)
# Centroid : (468, 608), farthest Point : (97, 689)
# Centroid : (495, 616), farthest Point : (916, 716)
# Centroid : (519, 619), farthest Point : (946, 681)
# Centroid : (509, 619), farthest Point : (82, 685)
# Centroid : (528, 622), farthest Point : (106, 719)
# Centroid : (527, 623), farthest Point : (84, 686)
# Centroid : (632, 602), farthest Point : (950, 680)
# Centroid : (620, 603), farthest Point : (913, 719)
# Centroid : (627, 605), farthest Point : (950, 674)
# Centroid : (620, 603), farthest Point : (947, 680)
# Centroid : (607, 604), farthest Point : (949, 671)
# Centroid : (589, 607), farthest Point : (945, 681)
# Centroid : (571, 611), farthest Point : (943, 680)
# Centroid : (569, 613), farthest Point : (951, 680)
# Centroid : (547, 615), farthest Point : (946, 681)
# Centroid : (534, 618), farthest Point : (948, 679)
# Centroid : (583, 580), farthest Point : (435, 719)
# Centroid : (526, 616), farthest Point : (94, 719)
# Centroid : (620, 594), farthest Point : (941, 685)
# Centroid : (621, 597), farthest Point : (951, 669)
# Centroid : (515, 612), farthest Point : (30, 719)
# Centroid : (491, 610), farthest Point : (46, 679)
# Centroid : (458, 608), farthest Point : (78, 685)
# Centroid : (504, 613), farthest Point : (944, 684)
# Centroid : (466, 592), farthest Point : (85, 719)
# Centroid : (466, 602), farthest Point : (46, 677)
# Centroid : (460, 610), farthest Point : (75, 685)
# Centroid : (464, 605), farthest Point : (77, 683)
# Centroid : (466, 604), farthest Point : (63, 683)
# Centroid : (579, 580), farthest Point : (438, 719)
# Centroid : (615, 599), farthest Point : (944, 683)
# Centroid : (582, 582), farthest Point : (440, 719)
# Centroid : (481, 607), farthest Point : (80, 684)
# Centroid : (463, 607), farthest Point : (78, 687)
# Centroid : (506, 616), farthest Point : (947, 682)
# Centroid : (462, 612), farthest Point : (81, 688)
# Centroid : (464, 611), farthest Point : (96, 691)
# Centroid : (468, 610), farthest Point : (86, 684)
# Centroid : (494, 617), farthest Point : (915, 705)
# Centroid : (471, 611), farthest Point : (107, 719)
# Centroid : (478, 616), farthest Point : (82, 688)
# Centroid : (500, 619), farthest Point : (949, 672)
# Centroid : (466, 607), farthest Point : (83, 683)
# Centroid : (497, 618), farthest Point : (916, 716)
# Centroid : (477, 614), farthest Point : (84, 685)
# Centroid : (465, 611), farthest Point : (88, 684)
# Centroid : (462, 612), farthest Point : (102, 719)
# Centroid : (475, 614), farthest Point : (84, 681)
# Centroid : (493, 618), farthest Point : (916, 715)
# Centroid : (460, 612), farthest Point : (72, 685)
# Centroid : (465, 610), farthest Point : (87, 686)
# Centroid : (504, 618), farthest Point : (951, 678)
# Centroid : (463, 610), farthest Point : (79, 685)
# Centroid : (476, 615), farthest Point : (94, 683)
# Centroid : (479, 609), farthest Point : (79, 684)
# Centroid : (506, 620), farthest Point : (916, 715)
# Centroid : (467, 609), farthest Point : (96, 685)
# Centroid : (468, 609), farthest Point : (103, 719)
# Centroid : (466, 609), farthest Point : (87, 684)
# Centroid : (463, 608), farthest Point : (75, 687)
# Centroid : (465, 609), farthest Point : (84, 687)
# Centroid : (519, 617), farthest Point : (79, 685)
# Centroid : (470, 606), farthest Point : (76, 685)
# Centroid : (469, 607), farthest Point : (73, 687)
# Centroid : (469, 605), farthest Point : (77, 685)
# Centroid : (509, 613), farthest Point : (944, 679)
# Centroid : (501, 611), farthest Point : (81, 687)
# Centroid : (505, 614), farthest Point : (946, 681)
# Centroid : (507, 613), farthest Point : (950, 674)
# Centroid : (469, 604), farthest Point : (74, 686)
# Centroid : (498, 615), farthest Point : (943, 679)
# Centroid : (469, 604), farthest Point : (82, 687)
# Centroid : (468, 603), farthest Point : (81, 686)
# Centroid : (484, 607), farthest Point : (92, 678)
# Centroid : (466, 605), farthest Point : (80, 686)
# Centroid : (487, 608), farthest Point : (88, 682)
# Centroid : (465, 607), farthest Point : (66, 684)
# Centroid : (466, 607), farthest Point : (87, 685)
# Centroid : (507, 615), farthest Point : (63, 686)
# Centroid : (470, 606), farthest Point : (82, 686)
# Centroid : (481, 611), farthest Point : (101, 719)
# Centroid : (501, 616), farthest Point : (946, 680)
# Centroid : (469, 609), farthest Point : (80, 681)
# Centroid : (466, 611), farthest Point : (81, 687)
# Centroid : (505, 616), farthest Point : (950, 667)
# Centroid : (478, 611), farthest Point : (93, 688)
# Centroid : (473, 613), farthest Point : (81, 687)
# Centroid : (478, 613), farthest Point : (88, 686)
# Centroid : (468, 607), farthest Point : (104, 719)
# Centroid : (466, 605), farthest Point : (104, 719)
# Centroid : (461, 610), farthest Point : (85, 683)
# Centroid : (465, 607), farthest Point : (102, 719)
# Centroid : (464, 606), farthest Point : (103, 719)
# Centroid : (460, 610), farthest Point : (72, 685)
# Centroid : (466, 607), farthest Point : (107, 699)
# Centroid : (468, 607), farthest Point : (84, 686)
# Centroid : (463, 605), farthest Point : (81, 682)
# Centroid : (466, 610), farthest Point : (85, 682)
# Centroid : (465, 610), farthest Point : (73, 688)
# Centroid : (466, 611), farthest Point : (101, 719)
# Centroid : (480, 611), farthest Point : (75, 687)
# Centroid : (462, 610), farthest Point : (61, 682)
# Centroid : (464, 608), farthest Point : (67, 685)
# Centroid : (467, 609), farthest Point : (86, 684)
# Centroid : (466, 611), farthest Point : (85, 682)
# Centroid : (471, 609), farthest Point : (89, 690)
# Centroid : (464, 611), farthest Point : (82, 681)
# Centroid : (463, 611), farthest Point : (84, 682)
# Centroid : (467, 606), farthest Point : (102, 719)
# Centroid : (464, 608), farthest Point : (74, 682)
# Centroid : (464, 609), farthest Point : (80, 686)
# Centroid : (466, 610), farthest Point : (75, 689)
# Centroid : (463, 610), farthest Point : (87, 684)
# Centroid : (459, 611), farthest Point : (74, 686)
# Centroid : (465, 609), farthest Point : (90, 681)
# Centroid : (503, 620), farthest Point : (949, 663)
# Centroid : (605, 586), farthest Point : (449, 719)
# Centroid : (468, 608), farthest Point : (87, 685)
# Centroid : (464, 610), farthest Point : (86, 685)
# Centroid : (458, 610), farthest Point : (100, 719)
# Centroid : (477, 614), farthest Point : (84, 684)
# Centroid : (461, 610), farthest Point : (76, 686)
# Centroid : (462, 610), farthest Point : (70, 685)
# Centroid : (473, 613), farthest Point : (76, 687)
# Centroid : (470, 611), farthest Point : (99, 719)
# Centroid : (502, 617), farthest Point : (914, 719)
# Centroid : (478, 614), farthest Point : (102, 719)
# Centroid : (466, 608), farthest Point : (86, 684)
# Centroid : (479, 612), farthest Point : (104, 719)
# Centroid : (475, 614), farthest Point : (77, 688)
# Centroid : (465, 608), farthest Point : (77, 686)
# Centroid : (464, 611), farthest Point : (71, 687)
# Centroid : (473, 615), farthest Point : (74, 687)
# Centroid : (463, 610), farthest Point : (81, 683)
# Centroid : (467, 611), farthest Point : (102, 719)
# Centroid : (463, 606), farthest Point : (102, 719)
# Centroid : (479, 611), farthest Point : (83, 685)
# Centroid : (468, 607), farthest Point : (78, 686)
# Centroid : (466, 607), farthest Point : (74, 687)
# Centroid : (509, 618), farthest Point : (946, 673)
# Centroid : (466, 609), farthest Point : (105, 719)
# Centroid : (467, 610), farthest Point : (107, 719)
# Centroid : (464, 609), farthest Point : (91, 683)
# Centroid : (464, 610), farthest Point : (75, 683)
# Centroid : (464, 611), farthest Point : (90, 684)
# Centroid : (465, 608), farthest Point : (87, 685)
# Centroid : (480, 608), farthest Point : (83, 685)
# Centroid : (468, 609), farthest Point : (106, 719)
# Centroid : (466, 607), farthest Point : (91, 681)
# Centroid : (464, 610), farthest Point : (80, 688)
# Centroid : (471, 610), farthest Point : (106, 692)
# Centroid : (466, 610), farthest Point : (100, 688)
# Centroid : (465, 610), farthest Point : (104, 719)
# Centroid : (517, 619), farthest Point : (950, 673)
# Centroid : (478, 614), farthest Point : (79, 686)
# Centroid : (465, 608), farthest Point : (94, 690)
# Centroid : (464, 609), farthest Point : (77, 687)
# Centroid : (463, 608), farthest Point : (85, 683)
# Centroid : (468, 609), farthest Point : (78, 685)
# Centroid : (479, 610), farthest Point : (79, 686)
# Centroid : (465, 608), farthest Point : (78, 683)
# Centroid : (466, 609), farthest Point : (82, 687)
# Centroid : (462, 612), farthest Point : (76, 682)
# Centroid : (467, 606), farthest Point : (81, 685)
# Centroid : (468, 608), farthest Point : (80, 685)
# Centroid : (464, 610), farthest Point : (84, 683)
# Centroid : (478, 611), farthest Point : (87, 680)
# Centroid : (470, 609), farthest Point : (101, 719)
# Centroid : (469, 609), farthest Point : (102, 719)
# Centroid : (466, 613), farthest Point : (76, 687)
# Centroid : (469, 610), farthest Point : (89, 682)
# Centroid : (505, 618), farthest Point : (946, 682)
# Centroid : (510, 618), farthest Point : (945, 683)
# Centroid : (480, 613), farthest Point : (88, 685)
# Centroid : (466, 609), farthest Point : (73, 686)
# Centroid : (468, 609), farthest Point : (70, 689)
# Centroid : (466, 607), farthest Point : (92, 678)
# Centroid : (467, 610), farthest Point : (87, 681)
# Centroid : (469, 612), farthest Point : (88, 719)
# Centroid : (469, 609), farthest Point : (85, 686)
# Centroid : (463, 606), farthest Point : (76, 689)
# Centroid : (463, 607), farthest Point : (77, 687)
# Centroid : (498, 615), farthest Point : (912, 719)
# Centroid : (462, 608), farthest Point : (102, 719)
# Centroid : (492, 617), farthest Point : (916, 715)
# Centroid : (497, 618), farthest Point : (945, 686)
# Centroid : (511, 620), farthest Point : (77, 687)
# Centroid : (458, 608), farthest Point : (80, 685)
# Centroid : (452, 605), farthest Point : (79, 688)
# Centroid : (488, 611), farthest Point : (915, 713)
# Centroid : (489, 614), farthest Point : (914, 703)
# Centroid : (454, 610), farthest Point : (81, 688)
# Centroid : (472, 610), farthest Point : (76, 684)
# Centroid : (570, 583), farthest Point : (434, 719)
# Centroid : (466, 607), farthest Point : (85, 686)
# Centroid : (466, 608), farthest Point : (84, 685)
# Centroid : (495, 616), farthest Point : (913, 715)
# Centroid : (464, 609), farthest Point : (87, 686)
# Centroid : (479, 613), farthest Point : (71, 689)
# Centroid : (464, 611), farthest Point : (74, 686)
# Centroid : (459, 609), farthest Point : (79, 685)
# Centroid : (462, 613), farthest Point : (92, 678)
# Centroid : (459, 613), farthest Point : (79, 684)
# Centroid : (472, 614), farthest Point : (79, 688)
# Centroid : (457, 609), farthest Point : (80, 687)
# Centroid : (459, 610), farthest Point : (82, 689)
# Centroid : (461, 611), farthest Point : (79, 688)
# Centroid : (459, 613), farthest Point : (72, 686)
# Centroid : (464, 613), farthest Point : (73, 686)
# Centroid : (470, 615), farthest Point : (70, 684)
# Centroid : (459, 611), farthest Point : (70, 688)
# Centroid : (463, 611), farthest Point : (77, 688)
# Centroid : (463, 611), farthest Point : (74, 685)
# Centroid : (460, 612), farthest Point : (71, 689)
# Centroid : (473, 617), farthest Point : (67, 687)
# Centroid : (457, 612), farthest Point : (82, 683)
# Centroid : (463, 613), farthest Point : (82, 682)
# Centroid : (458, 614), farthest Point : (78, 686)
# Centroid : (461, 611), farthest Point : (75, 688)
# Centroid : (475, 616), farthest Point : (75, 687)
# Centroid : (460, 612), farthest Point : (80, 688)
# Centroid : (464, 610), farthest Point : (83, 687)
# Centroid : (460, 613), farthest Point : (76, 685)
# Centroid : (475, 614), farthest Point : (69, 689)
# Centroid : (461, 613), farthest Point : (66, 686)
# Centroid : (460, 613), farthest Point : (66, 687)
# Centroid : (461, 612), farthest Point : (67, 687)
# Centroid : (458, 614), farthest Point : (68, 684)
# Centroid : (470, 613), farthest Point : (68, 685)
# Centroid : (472, 614), farthest Point : (65, 685)
# Centroid : (464, 612), farthest Point : (85, 684)
# Centroid : (461, 614), farthest Point : (84, 688)
# Centroid : (476, 616), farthest Point : (79, 688)
# Centroid : (473, 616), farthest Point : (72, 685)
# Centroid : (463, 611), farthest Point : (79, 686)
# Centroid : (461, 613), farthest Point : (77, 688)
